# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="whitegrid")

# %%
df = pd.read_csv('Car_data.csv')

# %%
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
df.shape
# Out:
# (11914, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   Engine HP          11845 non-null  float64
#  5   Engine Cylinders   11884 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11908 non-null  float64
#  9   Market Category    8172 non-null   object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# ...

# %%
df.rename(columns={ 'MSRP' : "Price"},inplace=True)

# %%
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
df.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# Price                   0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 715

# %%
df[df.duplicated()]
# Out:
#          Make     Model  Year             Engine Fuel Type  Engine HP  \
# 14        BMW  1 Series  2013  premium unleaded (required)      230.0
# 18       Audi       100  1992             regular unleaded      172.0
# 20       Audi       100  1992             regular unleaded      172.0
# 24       Audi       100  1993             regular unleaded      172.0
# 25       Audi       100  1993             regular unleaded      172.0
# ...       ...       ...   ...                          ...        ...
# 11481  Suzuki      X-90  1998             regular unleaded       95.0
# 11603   Volvo      XC60  2017             regular unleaded      302.0
# 11604   Volvo      XC60  2017             regular unleaded      240.0
# 11708  Suzuki       XL7  2008             regular unleaded      252.0
# 11717  Suzuki       XL7  2008             regular unleaded      252.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# ...

# %%
duplicates = df[df.duplicated(keep=False) | df.duplicated(keep='first')]

# %%
duplicates.sort_values(by=list(duplicates.columns))
# Out:
#         Make Model  Year             Engine Fuel Type  Engine HP  \
# 8536   Acura    RL  2010  premium unleaded (required)      300.0
# 8537   Acura    RL  2010  premium unleaded (required)      300.0
# 8539   Acura    RL  2011  premium unleaded (required)      300.0
# 8540   Acura    RL  2011  premium unleaded (required)      300.0
# 8544   Acura    RL  2012  premium unleaded (required)      300.0
# ...      ...   ...   ...                          ...        ...
# 8919   Volvo   S70  1998             regular unleaded      168.0
# 11600  Volvo  XC60  2017             regular unleaded      240.0
# 11604  Volvo  XC60  2017             regular unleaded      240.0
# 11601  Volvo  XC60  2017             regular unleaded      302.0
# 11603  Volvo  XC60  2017             regular unleaded      302.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 8536                6.0         AUTOMATIC    all wheel drive              4.0
# ...

# %%
df = df.drop_duplicates()

# %%
df['Transmission Type'].unique()
# Out:
# array(['MANUAL', 'AUTOMATIC', 'AUTOMATED_MANUAL', 'DIRECT_DRIVE',
#        'UNKNOWN'], dtype=object)

# %%
df.loc[1289,'Transmission Type'] = 'UNKNOWN'

# %%
# Unknown Beacuse vehicles existed in more than 1 types of transmission
df[df['Transmission Type'] == 'UNKNOWN']
# Out:
#             Make     Model  Year  Engine Fuel Type  Engine HP  \
# 1289  Oldsmobile   Achieva  1997  regular unleaded      150.0
# 1290  Oldsmobile   Achieva  1997  regular unleaded      150.0
# 4691     Pontiac  Firebird  2000  regular unleaded      305.0
# 4692     Pontiac  Firebird  2000  regular unleaded      305.0
# 4693     Pontiac  Firebird  2000  regular unleaded      305.0
# 6158         GMC     Jimmy  1999  regular unleaded      190.0
# 6160         GMC     Jimmy  1999  regular unleaded      190.0
# 6165         GMC     Jimmy  2000  regular unleaded      190.0
# 6174         GMC     Jimmy  2000  regular unleaded      190.0
# 6366    Chrysler  Le Baron  1993  regular unleaded      100.0
# 6368    Chrysler  Le Baron  1993  regular unleaded      100.0
# 8042       Dodge   RAM 150  1991  regular unleaded      125.0
#
#       Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 1289               4.0           UNKNOWN  front wheel drive              2.0
# ...

# %%
df.shape
# Out:
# (11199, 16)

# %%
df.nunique()
# Out:
# Make                   48
# Model                 915
# Year                   28
# Engine Fuel Type       10
# Engine HP             356
# Engine Cylinders        9
# Transmission Type       5
# Driven_Wheels           4
# Number of Doors         3
# Market Category        71
# Vehicle Size            3
# Vehicle Style          16
# highway MPG            59
# city mpg               69
# Popularity             48
# Price                6049
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3376
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# Price                   0
# dtype: int64

# %%
mark = df.groupby('Market Category')['Price'].agg(['mean','count'])

# %%
mark
# Out:
#                                                          mean  count
# Market Category
# Crossover                                        30015.998140   1075
# Crossover,Diesel                                 54622.142857      7
# Crossover,Exotic,Luxury,High-Performance         83000.000000      1
# Crossover,Exotic,Luxury,Performance              72000.000000      1
# Crossover,Factory Tuner,Luxury,High-Performance  91916.153846     26
# ...                                                       ...    ...
# Luxury,Hybrid                                    54789.519231     52
# Luxury,Performance                               46671.525038    659
# Luxury,Performance,Hybrid                        66921.818182     11
# Performance                                      28311.694231    520
# Performance,Hybrid                               31900.000000      1
#
# [71 rows x 2 columns]

# %% [markdown]
# # Engine HP V/s Price

# %%
plt.figure(figsize=(10,5))
sns.regplot(x = 'Engine HP', y = 'Price',data = df)
plt.xlabel("Engine HP")
plt.ylabel('Price')
plt.title("Engine HP V/S Price")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.barplot(x = df['Transmission Type'], y = df['Price'],data = df)
plt.ylabel('Price')
plt.title('Effect of Transmission Type on Price')
plt.show()

# %%
df.groupby('Transmission Type')['Price'].mean()
# Out:
# Transmission Type
# AUTOMATED_MANUAL    108718.987342
# AUTOMATIC            41816.124307
# DIRECT_DRIVE         47351.250000
# MANUAL               28267.919894
# UNKNOWN               3647.833333
# Name: Price, dtype: float64

# %%
plt.figure(figsize=(50,20))
sns.barplot(x = df['Make'], y = df['Price'],data=df)
plt.ylabel('Price')
plt.title('Average Price of Each Model')
plt.show()

# %%
plt.figure(figsize=(29,10))
sns.barplot(x = df['Vehicle Style'],y = df['Price'],data= df)
plt.ylabel('Price')
plt.title('Effect of Vehicle Style on Price')
plt.show()

# %%
plt.figure(figsize=(29,10))
sns.countplot(x = df['Vehicle Style'], data =df)
# Out:
# <Axes: xlabel='Vehicle Style', ylabel='count'>

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Market Category', 'Vehicle Size', 'Vehicle Style',
#        'highway MPG', 'city mpg', 'Popularity', 'Price'],
#       dtype='object')

# %%
df.groupby('Transmission Type')[['highway MPG', 'city mpg']].mean().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Transmission Type'>

# %% [markdown]
# # Average price per each company

# %%
avg_car = df.groupby('Make')['Price'].mean()

# %%
avg_car
# Out:
# Make
# Acura            3.508749e+04
# Alfa Romeo       6.160000e+04
# Aston Martin     1.981235e+05
# Audi             5.457412e+04
# BMW              6.216256e+04
# Bentley          2.471693e+05
# Bugatti          1.757224e+06
# Buick            2.903419e+04
# Cadillac         5.636827e+04
# Chevrolet        2.907473e+04
# Chrysler         2.672296e+04
# Dodge            2.485705e+04
# FIAT             2.267024e+04
# Ferrari          2.382188e+05
# Ford             2.851131e+04
# GMC              3.244409e+04
# Genesis          4.661667e+04
# HUMMER           3.646441e+04
# Honda            2.665515e+04
# Hyundai          2.492626e+04
# Infiniti         4.264027e+04
# Kia              2.551376e+04
# Lamborghini      3.315673e+05
# Land Rover       6.806709e+04
# Lexus            4.754907e+04
# Lincoln          4.386082e+04
# Lotus            6.837714e+04
# Maserati         1.136845e+05
# Maybach          5.462219e+05
# Mazda            2.041662e+04
# McLaren          2.398050e+05
# ...

# %%
plt.figure(figsize=(8,5))
avg_car.plot(kind = 'bar')
plt.title("Average Price of car for Each Company")
# Out:
# Text(0.5, 1.0, 'Average Price of car for Each Company')

# %%
plt.figure(figsize=(8,5))
sns.regplot(x = 'Engine Cylinders', y = 'highway MPG' ,data =df)
plt.show()
